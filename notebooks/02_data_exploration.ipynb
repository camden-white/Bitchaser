# %%
from pathlib import Path

from bitchaser.data.load import load_processed

# %%
df = load_processed(Path("data/processed/btc_ohlc.parquet"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = load_processed(Path("data/processed/btc_ohlc.parquet"))
#
# File ~/Work/Projects/BitChaser/src/bitchaser/data/load.py:45, in load_processed(path)
#      33 """Load processed data from a Parquet file.
#      34
#      35 Args:
#    (...)     42     FileNotFoundError: If the Parquet file does not exist.
#      43 """
#      44 if not path.is_file():
# ---> 45     raise FileNotFoundError(f"Processed data file not found: {path}")
#      47 return pd.read_parquet(path)
#
# FileNotFoundError: Processed data file not found: data/processed/btc_ohlc.parquet

# %%
print(df.head())

# %%
print(df.tail())

# %%
print(df.info())

# %%
print(df.describe())
