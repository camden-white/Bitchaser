# %%
import pandas

# %%
path = "../data/raw/BTCUSD_OHLC.csv"
df = pandas.read_csv(path)

# %%
print(df.head())
# Out:
#         Start         End      Open      High       Low     Close  \
# 0  2024-06-27  2024-06-28  60882.90  62338.43  60666.19  61646.05
# 1  2024-06-26  2024-06-27  61733.99  62357.58  60761.24  60761.24
# 2  2024-06-25  2024-06-26  60317.99  62231.16  60272.58  61789.98
# 3  2024-06-24  2024-06-25  63168.03  63316.01  58946.24  60382.81
# 4  2024-06-23  2024-06-24  64276.04  64521.03  63290.43  63290.43
#
#          Volume    Market Cap
# 0  1.215887e+11  1.208392e+12
# 1  1.017576e+11  1.210544e+12
# 2  1.050312e+11  1.208415e+12
# 3  8.828355e+10  1.211101e+12
# 4  6.853945e+10  1.265327e+12

# %%
print(df.columns.tolist())
# Out:
# ['Start', 'End', 'Open', 'High', 'Low', 'Close', 'Volume', 'Market Cap']

# %%
print(df.dtypes)
# Out:
# Start             str
# End               str
# Open          float64
# High          float64
# Low           float64
# Close         float64
# Volume        float64
# Market Cap    float64
# dtype: object

# %%
print(df.shape)
# Out:
# (5095, 8)
